# %%
import vertexai
from vertexai.preview import reasoning_engines

vertexai.init(project="icarus-agent-26", location="europe-west2")

# Connect to the deployed reasoning engine
remote_app = reasoning_engines.ReasoningEngine('projects/463466170878/locations/europe-west2/reasoningEngines/2229009136664707072')

# Query the agent (using the 'stream_query' method that we verified)
response_stream = remote_app.stream_query(message="Hello, TracerLensAi!")
for chunk in response_stream:
    print(chunk)

# %%
import vertexai
from vertexai.preview import reasoning_engines

vertexai.init(project='icarus-agent-26', location='europe-west2')

remote_app = reasoning_engines.ReasoningEngine('projects/463466170878/locations/europe-west2/reasoningEngines/4773965138594103296')

print("Sending test query to TracerLensAi...")
response_stream = remote_app.stream_query(message="Hello, TracerLensAi! Tell me about structural causal models.")

for chunk in response_stream:
    print(chunk, end="", flush=True)
# Out:
# Sending test query to TracerLensAi...
